# %%
import pandas as pd

df=pd.read_csv('car_price_prediction.csv')
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep  \
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df["Levy"] = df["Levy"].str.replace("-","0")
df['Levy'] = df['Levy'].astype(int)
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep  \
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     0          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df["Mileage"] = df["Mileage"].str.replace(" km","")
df['Mileage'] = df['Mileage'].astype(int)
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep  \
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     0          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df = df.loc[(df['Price'] > 1000) & (df['Price'] < 1000000)]
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep  \
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     0          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19231  45772306   5802  1055  MERCEDES-BENZ    E 350        2013      Sedan
# 19232  45798355   8467     0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
#
# ...

# %%
df['Prod. year'] = pd.to_datetime(df['Prod. year'], format='%Y')
df['Prod. year'] = df['Prod. year'].dt.year
df
# Out:
# C:\Users\teren\AppData\Local\Temp\ipykernel_23120\1055046134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Prod. year'] = pd.to_datetime(df['Prod. year'], format='%Y')
# C:\Users\teren\AppData\Local\Temp\ipykernel_23120\1055046134.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Prod. year'] = df['Prod. year'].dt.year
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep  \
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     0          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19231  45772306   5802  1055  MERCEDES-BENZ    E 350        2013      Sedan
# 19232  45798355   8467     0  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
#
# ...

# %%
if df['ID'].duplicated().any():
    print("Il y a des doublons dans la colonne 'ID'")
else:
    print("Il n'y a pas de doublons dans la colonne 'ID'")
# Out:
# Il n'y a pas de doublons dans la colonne 'ID'

# %%
duplicates = df[df.duplicated(['ID'], keep=False)]['ID']
duplicates.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.loc[df['ID'] == 45723475]
# Out:
#             ID  Price  Levy Manufacturer   Model  Prod. year Category
# 2494  45723475  19444   502         FORD  Fusion        2013    Sedan  \
#
#      Leather interior Fuel type Engine volume  Mileage  Cylinders
# 2494               No    Petrol     1.5 Turbo   100000        4.0  \
#
#      Gear box type Drive wheels   Doors       Wheel  Color  Airbags
# 2494     Automatic        Front  04-May  Left wheel  Black        8

# %%
df.nunique()
# Out:
# ID                  16394
# Price                2237
# Levy                  540
# Manufacturer           64
# Model                1558
# Prod. year             51
# Category               11
# Leather interior        2
# Fuel type               7
# Engine volume         107
# Mileage              6881
# Cylinders              13
# Gear box type           4
# Drive wheels            3
# Doors                   3
# Wheel                   2
# Color                  16
# Airbags                17
# dtype: int64

# %%
df.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                  int32
# Manufacturer         object
# Model                object
# Prod. year            int32
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage               int32
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object
